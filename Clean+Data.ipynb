# %%
import pandas as pd
data = pd.read_csv('US_Accidents_June20.csv')
data.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng          ...           Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          ...                False
# 1  39.928059 -82.831184      NaN      NaN          ...                False
# 2  39.063148 -84.032608      NaN      NaN          ...                False
# 3  39.747753 -84.205582      NaN      NaN          ...                False
# 4  39.627781 -84.188354      NaN      NaN          ...                False
#
# ...

# %%
len(data)
# Out:
# 3513617

# %%
data.isnull().sum(axis = 0)
# Out:
# ID                             0
# Source                         0
# TMC                      1034799
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  2478818
# End_Lng                  2478818
# Distance(mi)                   0
# Description                    1
# Number                   2262864
# Street                         0
# Side                           0
# City                         112
# County                         0
# State                          0
# Zipcode                     1069
# Country                        0
# Timezone                    3880
# Airport_Code                6758
# Weather_Timestamp          43323
# Temperature(F)             65732
# Wind_Chill(F)            1868249
# Humidity(%)                69687
# Pressure(in)               55882
# Visibility(mi)             75856
# ...

# %%
data['TMC'].fillna(value=201, inplace=True)

# %%
data['Precipitation(in)'] = data['Precipitation(in)'].fillna(data['Precipitation(in)'].median())
data['Visibility(mi)'] = data['Visibility(mi)'].fillna(data['Visibility(mi)'].median())
data['Temperature(F)'] = data['Temperature(F)'].fillna(data['Temperature(F)'].median())
data['Humidity(%)'] = data['Humidity(%)'].fillna(data['Humidity(%)'].median())

# %% [markdown]
# data.drop(['End_Lat', 'End_Lng', 'Number',"Timezone", "Airport_Code", "Weather_Timestamp", "Zipcode",'Wind_Chill(F)' ], inplace=True)
# data.isnull().sum(axis = 0)

# %%
data.loc[data['Wind_Direction'] == 'Calm', 'Wind_Speed(mph)'] = 0

# %%
data.isnull().sum(axis = 0)
# Out:
# ID                           0
# Source                       0
# TMC                          0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# Description                  1
# Street                       0
# Side                         0
# City                       112
# County                       0
# State                        0
# Country                      0
# Temperature(F)               0
# Humidity(%)                  0
# Pressure(in)             55882
# Visibility(mi)               0
# Wind_Direction           58874
# Wind_Speed(mph)          86327
# Precipitation(in)            0
# Weather_Condition        76138
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# ...

# %%
data.drop(['Pressure(in)'], axis = 1)
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# 5              A-6  MapQuest  201.0         3  2016-02-08 07:44:26
# 6              A-7  MapQuest  201.0         2  2016-02-08 07:59:35
# 7              A-8  MapQuest  201.0         3  2016-02-08 07:59:58
# 8              A-9  MapQuest  201.0         2  2016-02-08 08:00:40
# 9             A-10  MapQuest  201.0         3  2016-02-08 08:10:04
# 10            A-11  MapQuest  201.0         3  2016-02-08 08:14:42
# 11            A-12  MapQuest  241.0         3  2016-02-08 08:21:27
# 12            A-13  MapQuest  201.0         2  2016-02-08 08:36:34
# ...

# %%
print('Missing values: ', data.columns[(100*data.isnull().sum()/data.shape[0])>0].tolist())
# Out:
# ('Missing values: ', ['Description', 'City', 'Pressure(in)', 'Wind_Direction', 'Wind_Speed(mph)', 'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'])

# %%
data.isnull().sum(axis = 0)
# Out:
# ID                           0
# Source                       0
# TMC                          0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# Description                  1
# Street                       0
# Side                         0
# City                       112
# County                       0
# State                        0
# Country                      0
# Temperature(F)               0
# Humidity(%)                  0
# Pressure(in)             55882
# Visibility(mi)               0
# Wind_Direction           58874
# Wind_Speed(mph)          86327
# Precipitation(in)            0
# Weather_Condition        76138
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# ...

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum(axis = 0)
# Out:
# ID                       0
# Source                   0
# TMC                      0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# Side                     0
# City                     0
# County                   0
# State                    0
# Country                  0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# ...

# %%
len(data)
# Out:
# 3410983

# %%
data.to_csv('US_Accidents_filtered.csv')
